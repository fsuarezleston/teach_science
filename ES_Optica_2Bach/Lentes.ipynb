# %% [markdown]
# # Lentes

# %% [markdown]
# Fabián Suárez Lestón
#
# f.suarez.leston@gmail.com

# %% [markdown]
# Esta notebook está diseñada para la enseñanza de los fundamentos de las lentes en la materia de Física de 2º de Bachillerato.

# %% [markdown]
# #### __Instrucciones de la notebook__

# %% [markdown]
# Para usar esta notebook no es necesario que instales nada ni tengas conocimientos de programación. El código escrito por tu profesor te permitirá ver las explicaciones y ver el efecto de algunos parámetros relevantes en la formación del arcoiris.
#
# Es necesario que ejecutes **todas** las celdas de código para que funcione correctamente. Los parámetros que puedes modificar aparecerán con deslizadores antes de cada representación.
#
# En las celdas que tengan a la izquiera unos corchetes "[]" (con o sin un número entre ellos) y en las que se te pida escribir, debes cambiar el "None" por el número que se te pide. El separador decimal ha de ser el punto ".". Por ejemplo, si se te pide tu altura en metros y mides 1,70 m, entonces la casilla

# %%
altura = None

# %% [markdown]
# Debes modificarla para obtener

# %%
altura = 1.70

# %% [markdown]
# Las siguientes celdas son definiciones importantes para luego. Ejecútalas y pasa a la siguiente sección.

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

import ipywidgets

from definitions import *
from matplotlib import animation
from IPython.display import display, HTML, display_html
from ipywidgets import interact, interact_manual, IntProgress
from matplotlib.widgets import Slider

plt.rcParams["animation.html"] = "jshtml"

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Un rayo de luz atraviesa una gota de agua (otra vez)

# %% [markdown]
# Hemos visto el comportamiento de un rayo de luz al atravesar una interfase esférica entre el aire ($n=1$) y un medio de índice de refracción $n$ cuando hemos estudiado el proceso de formación del arcoíris

# %%
h = 0.6
n = RefrIndex(750)

fig, ax = plt.subplots( figsize=(6,6), tight_layout=True )
PlotRaysDroplet( fig, ax, h, n, alpha_refracted_I=0.9, alpha_reflected_I=0.1, alpha_reflected_R=0.8, alpha_refracted_R=0.1, 
                alpha_refracted_E=0, alpha_reflected_E=0, draw_local_axis_E=False, draw_angles_E=False  )

# %% [markdown]
# Pero, al mismo tiempo que parte del rayo de luz se refracta en la cara opuesta de la gota, otra emerge refractada: La mayor parte de la luz que incide en una gota de agua la atraviesa, ¡las gotas de agua no son opacas!

# %%
fig, ax = plt.subplots( figsize=(6,6), tight_layout=True )
PlotRaysDroplet( fig, ax, h, n, alpha_refracted_I=0.96, alpha_reflected_I=0.4, alpha_reflected_R=0.4, alpha_refracted_R=0.92, 
                alpha_refracted_E=0, alpha_reflected_E=0, draw_local_axis_E=False, draw_angles_E=False  )

# %% [markdown]
# ¡Un rayo de luz que proviene del infinito experimenta un cambio de dirección al atravesar la gota de agua!

# %% [markdown]
# Veamos ahora que pasa con un haz de rayos que atraviesan la gota muy cerca de su eje:

# %%
PlotRaysDroplet_Paraxial( [ 1, 0.96, 0.92 ] )
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %% [markdown]
# ¡Todos los rayos se concentran en un mismo punto! Este punto se denomina foco (foco imágen, $f'$), y es de vital importancia en la fabricación de una lente.
#
# En el estudio de las lentes asumiremos que son ideales; esto es, en su superficie no se produce reflexión de la luz, sino que toda la radiación que incide sobre ellas las atraviesa.

# %% [markdown]
# ### Cómo construir una lente

# %% [markdown]
# Una lente es un medio que permite atravesar la luz, pero que cambia su dirección de propagación.
#
# Las lentes que estudiaremos están formadas por dos superficies esféricas (lentes esféricas) que encierran un medio de índice de refracción $n$, y nos centraremos en los rayos de luz que la atraviesan cerca de su eje (aproximación paraxial).
#
# El caso anterior de la gota de agua es un caso particular de una lente formada por dos superficies esféricas de igual radio de curvatura (el radio de la gota), pero podemos construir una lente con distintos radios de curvatura:

# %%
fig, ax = plt.subplots( figsize=(18,6), tight_layout=True )
PlotThinLens( fig, ax, h=[0.2, 0.15, 0.1, 0.05, -0.2, -0.15, -0.1, -0.05], n=1.5, R1=4, R2=-2, c1=-0.4, c2=0.4, xlims=( -2, 6 ), color="yellow", alpha_rays=1, alpha_virtual=0 )

# %% [markdown]
# Para determinar la posición del foco, podemos hacer uso de la ecuación del fabricante de lentes:
# $$
# \frac{1}{f'}=(n-1)\left(\frac{1}{R_1}-\frac{1}{R_2}\right)
# $$
#
# Esta ecuación es válida para lentes delgadas rodeadas por aire: esto es, lentes donde los radios de curvatura sean mucho mayores que el grosor. Si queremos usar una lente en otro medio, debemos cambiar el término $(n-1)$ por $(n/n_\mathrm{medio}-1)$

# %% [markdown]
# En la ecuación anterior usamos la norma DIN: distancias medidas hacia la izquierda o hacia abajo son negativas, mientras que hacia la derecha o hacia arriba son positivas. En el caso de la gota de agua, tendríamos que $R_1=R$ y $R_2=-R$, de modo que $f'=(2R)/(n-1)$.

# %% [markdown]
# ## Tipos de lentes

# %% [markdown]
# No es necesario que los radios de curvatura sean siempre $R_1>0$ y $R_2<0$. De hecho, hay distintos tipos de lentes en función de como sean los radios de curvatura.
#
# - __Lentes convergentes__: concentran los rayos de luz en un punto, llamado foco. Son más gruesas en el centro que en sus extremos. La distancia entre el foco y la lente –distancia focal– es, por tanto, positiva ($f'>0$). En función de los radios de las superficies pueden ser:
#     - Biconvexas: $R_1>0$ y $R_2<0$.
#     - Plano-convexas:  $R_1>0$ y $R_2=\infty$.
#     - Menisco-convexas: $R_1>0$ y $R_2>0$, pero $R_2>R_1$.
#
# - __Lentes divergentes__: los rayos de luz se dispersan a su salida, pero parecen provenir de un punto situado antes de la lente. Este es su foco y, por tanto, la distancia focal es negativa ($f'<0$). En función de los radios de las superficies distinguimos:
#     - Bicóncavas: $R_1<0$ y $R_2>0$.
#     - Plano-cóncavas:  $R_1=\infty$ y $R_2>0$.
#     - Menisco-cóncavas: $R_1>0$ y $R_2>0$, pero $R_1>R_2$.
#
# - __Lámina de caras paralelas__: En este caso, $R_1=R_2=\infty$, por lo que los rayos de luz que inciden perpendicularmente no ven su trayectoria alterada.

# %% [markdown]
# #### ___Simulación___: Características de las lentes
#
# Mediante esta herramienta puedes comprobar como los distintos parámetros —radios de curvatura e índice de refracción— afectan la propagación de los rayos de luz.
#
# Ten en cuenta que las magnitudes que puedes controlar son: $1/R_1$, $1/R_2$ y $n$. Así, si quieres probar a construir una lente con una cara plana puedes tener en cuenta que $1/R=1/\infty=0$
#
# _Nota:_ Como puedes comprobar, se dan dos distancias focales. La primera es la calculada por el simulador, y se corresponde a un caso de lente con un cierto grosor. La segunda es la calculada según la fórmula. El valor simulado es bastante parecido al modelo, salvo en los casos en los que $R_1\approx R_2$.

# %%
@interact(inv_R1=ipywidgets.widgets.FloatSlider(min=-0.5, max=0.5, step=0.0001, value=0.25), 
          inv_R2=ipywidgets.widgets.FloatSlider(min=-0.5, max=0.5, step=0.0001, value=-0.5), 
          n=ipywidgets.widgets.FloatSlider(min=1, max=5, step=0.01, value=1.33))
def InteractThinLens( inv_R1, inv_R2, n ):
    with np.errstate(divide='ignore'):
        R1 = np.float64(1.)/np.float64(inv_R1)
        R2 = np.float64(1.)/np.float64(inv_R2)
    fig, ax = plt.subplots( figsize=(13,6), tight_layout=True )
    PlotThinLens( fig, ax, h=[0.15, -0.15, -0.1, 0.1, -0.05, 0.05 ], n=n, R1=R1, R2=R2, c1=-0.3, c2=0.3, xlims=( -2, 6 ), color="yellow", alpha_rays=1, alpha_virtual=0.3, report=True )
# Out:
# interactive(children=(FloatSlider(value=0.25, description='inv_R1', max=0.5, min=-0.5, step=0.0001), FloatSlid…

# %% [markdown]
# ## Cómo determinar la imagen formada por una lente

# %% [markdown]
# ### Trazado de rayos

# %% [markdown]
# Como hemos visto, las lentes convergentes concentran los rayos que inciden sobre ellas en un punto, su foco.
#
# En Óptica Geométrica, las lentes convergentes se representan como una barra vertical terminada en flechas apuntando hacia afuera, mientras que una lente divergente se representa con las flechas apuntando en la dirección contraria.

# %%
PlotLensImageFocusRays()

# %% [markdown]
# Hai otra consideración importante, y es que un rayo de luz que atraviesa una lente delgada ($d\rightarrow0$) por su centro, atraviesa la lente sin desviarse.

# %%
PlotLensCenterRays( )

# %% [markdown]
# Hay otro punto igualmente importante, el foco objeto $f$, el punto del eje óptico tal que $f=-f'$.
#
# Cualquier rayo que atraviese el foco objeto emergerá de la lente paralelo al eje óptico

# %%
PlotLensObjectFocusRays()

# %% [markdown]
# Sabiendo esto, ¿cómo podemos determinar dónde se formará la imagen de un cierto objeto por efecto de una lente?
#
# Basta con trazar dos rayos cualesquiera de los siguientes:
# -   Uno paralelo al eje pasando por el objeto, que sabemos que atravesará el foco imágen.
# -   Uno pasando por el centro de la lente y el objeto, que sabemos que atravesará la lente sin desviarse.
# -   Uno pasando por el foco objeto y el objeto, que emergerá paralelo al eje.
#
# El punto de intersección se correspondrá a la imagen del objeto.

# %%
PlotLensImage( s=-2.5, f=1, y=0.5 )

# %% [markdown]
# En algunos casos, los rayos divergerán. Sin embargo, si los rayos que emergen de la lente se proyectan en el espacio objeto, habrá un punto en el que se intersequen

# %%
PlotLensImage( s=-2.5, f=-1, y=0.5 )

# %% [markdown]
# ### Determinación matemática de la imagen formada

# %% [markdown]
# Si situamos un objeto a una cierta distancia $s$ de la lente (distancia objeto, $s<0$) y a una cierta altura $y$ sobre el eje óptico, se formará una imagen de este a una nueva distancia $s'$ (distancia imagen) y de un cierto tamaño $y'$ (altura imagen).
#
# Para determinar el valor de $s'$ podemos hacer uso de la ecuación de la lente:
#
# $$
# \frac{1}{s'}-\frac{1}{s}=\frac{1}{f'}
# $$
#
# Mientras que para determinar $y'$ podemos usar la relación
#
# $$
# M = \frac{s'}{s} = \frac{y'}{y},
# $$
#
# donde $M$ recibe el nombre de magnificación. Este par de ecuaciones sigue las normas DIN: distancias a la derecha de la lente y hacia arriba del eje óptico son positivas.

# %% [markdown]
# La imagen generada puede ser clasificada en función a tres atributos.
#
# En función de los rayos que la forman
# -   Real, si la imagen se forma debido a la intersección de los rayos refractados por la lente. En general, esto significa que $s'>0$.
# -   Virtual, si para la formación de la imagen es necesario usar la proyección de los rayos refractados en el espacio objeto. Esto se traduce en que $s'<0$.
#
# En función de la posición relativa de la imagen respecto al eje óptico:
# -   Derecha, si $y'\cdot y>0$; esto es, si la imagen está del mismo lado del eje óptico que el objeto.
# -   Invertida, si $y'\cdot y<0$; esto es, si la imagen está en el lado opuesto del eje óptico respecto al objeto.
#
# En función del tamaño de la imagen respecto al objeto:
# -   Mayor o aumentada, si $|y'|>|y|$. La imagen es mayor que el objeto.
# -   Menor o reducida, si $|y'|<|y|$. La imagen es menor que el objeto.

# %% [markdown]
# #### ___Simulación___: Imagen formada por una lente

# %% [markdown]
# Mediante esta herramienta puedes controlar la distancia de un objeto a una lente convergente. Úsala para explorar como es la imagen formada.
#
# Por simplicidad, las distancias en ele eje $x$ se miden en unidades de la distancia focal imagen, por lo que $f'=\pm1$. En el eje $y$, las distancias se miden en función de la altura de objeto.

# %%
@interact( s=ipywidgets.widgets.FloatSlider(min=-3, max=-0.01, step=0.01, value=-3),
           f=ipywidgets.widgets.FloatSlider(min=-1, max=1, step=2, value=1) )
def InteractLensImage( s, f ):
    PlotLensImage( s=s, f=f, y=0.5, report=True )
# Out:
# interactive(children=(FloatSlider(value=-3.0, description='s', max=-0.01, min=-3.0, step=0.01), FloatSlider(va…

# %% [markdown]
# ## ___Reflexiona___
#
# Intenta responder a estas preguntas sobre el proceso de formación de imágenes mediante lentes.

# %% [markdown]
# __1)__ ¿Por qué los rayos de luz que atraviesan el centro de una lente delgada salen sin desviarse?

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# __2)__ Si creamos una lente esférica de radios $R_1$ y $R_2$ con un material de índice de refracción $n$, ¿cual es su distancia focal si la usamos al aire libre?

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# y si ahora creamos una lente igual, pero hecha de aire y la sumergimos en un medio de índice $n$, ¿cómo cambia la distancia focal?

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# __3__) Determina como es la imagen creada por una lente convergente si el objeto se sitúa...
#
# -   _3.1_. A más de dos veces la distancia focal de la lente:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _3.2_. A una distancia igual a dos veces la distancia focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _3.3_. A una distancia entre 1 y 2 veces la focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _3.4_. A una distancia igual a la focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _3.5_. A una distancia menor que la focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# __4__) Determina como es la imagen creada por una lente divergente si el objeto se sitúa...
#
# -   _4.1_. A más de dos veces la distancia focal de la lente:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _4.2_. A una distancia igual a dos veces la distancia focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _4.3_. A una distancia entre 1 y 2 veces la focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _4.4_. A una distancia igual a la focal:

# %% [raw]
# Escribe tu respuesta aquí

# %% [markdown]
# - _4.5_. A una distancia menor que la focal:

# %% [raw]
# Escribe tu respuesta aquí
